# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 708

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | husavik
# Processing Record 2 of Set 1 | novonikolsk
# Processing Record 3 of Set 1 | alice springs
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | namangan
# Processing Record 9 of Set 1 | tiarei
# Processing Record 10 of Set 1 | marystown
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | trincomalee
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | shimoda
# Processing Record 16 of Set 1 | kenai
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | tommot
# Processing Record 26 of Set 1 | chamba
# Processing Record 27 of Set 1 | san julian
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | inhambane
# Processing Record 31 of Set 1 | fereydunshahr
# Processing Record 32 of Set 1 | umm lajj
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | flinders
# Processing Record 36 of Set 1 | samarai
# Processing Record 37 of Set 1 | flin flon
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | alofi
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | zelenets
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | broome
# Processing Record 45 of Set 1 | chikoy
# City not found. Skipping...
# Processing Record 46 of Set 1 | lamar
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | beringovskiy
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | trelew
# Processing Record 1 of Set 2 | nome
# Processing Record 2 of Set 2 | klaksvik
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | sur
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | los llanos de aridane
# Processing Record 10 of Set 2 | sao filipe
# Processing Record 11 of Set 2 | ambilobe
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | axim
# Processing Record 14 of Set 2 | nara
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | ahipara
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | maldonado
# Processing Record 20 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | gao
# Processing Record 23 of Set 2 | taunggyi
# Processing Record 24 of Set 2 | fort nelson
# Processing Record 25 of Set 2 | vardo
# Processing Record 26 of Set 2 | hokitika
# Processing Record 27 of Set 2 | aklavik
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | yenagoa
# Processing Record 30 of Set 2 | pisco
# Processing Record 31 of Set 2 | dondo
# Processing Record 32 of Set 2 | two rivers
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | norfolk
# Processing Record 35 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 2 | hervey bay
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | daru
# Processing Record 40 of Set 2 | toamasina
# Processing Record 41 of Set 2 | faanui
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 2 | ossora
# Processing Record 45 of Set 2 | quatre cocos
# Processing Record 46 of Set 2 | odweyne
# Processing Record 47 of Set 2 | ayame
# Processing Record 48 of Set 2 | lorengau
# Processing Record 49 of Set 2 | port maria
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | guilin
# Processing Record 2 of Set 3 | araouane
# Processing Record 3 of Set 3 | severo-kurilsk
# Processing Record 4 of Set 3 | port-cartier
# Processing Record 5 of Set 3 | guatire
# Processing Record 6 of Set 3 | batagay
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | sandviken
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 11 of Set 3 | atambua
# Processing Record 12 of Set 3 | asasa
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | altamira
# Processing Record 15 of Set 3 | vila
# Processing Record 16 of Set 3 | sa kaeo
# Processing Record 17 of Set 3 | pringsewu
# Processing Record 18 of Set 3 | darnah
# Processing Record 19 of Set 3 | ayan
# Processing Record 20 of Set 3 | kruisfontein
# Processing Record 21 of Set 3 | sao jose da coroa grande
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | wewak
# Processing Record 24 of Set 3 | nelson bay
# Processing Record 25 of Set 3 | mabaruma
# Processing Record 26 of Set 3 | meulaboh
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | vanavara
# Processing Record 29 of Set 3 | kachikau
# City not found. Skipping...
# Processing Record 30 of Set 3 | san quintin
# Processing Record 31 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 3 | quetzaltepec
# City not found. Skipping...
# Processing Record 33 of Set 3 | celestun
# Processing Record 34 of Set 3 | marau
# Processing Record 35 of Set 3 | dunedin
# Processing Record 36 of Set 3 | olafsvik
# Processing Record 37 of Set 3 | albany
# Processing Record 38 of Set 3 | muisne
# Processing Record 39 of Set 3 | half moon bay
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | cabadiangan
# Processing Record 42 of Set 3 | emerald
# Processing Record 43 of Set 3 | port moresby
# Processing Record 44 of Set 3 | georgetown
# Processing Record 45 of Set 3 | loiza
# Processing Record 46 of Set 3 | belmonte
# Processing Record 47 of Set 3 | talnakh
# Processing Record 48 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 3 | carire
# Processing Record 50 of Set 3 | bambous virieux
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | maues
# Processing Record 3 of Set 4 | sungaipenuh
# Processing Record 4 of Set 4 | khani
# Processing Record 5 of Set 4 | port hedland
# Processing Record 6 of Set 4 | mitsamiouli
# Processing Record 7 of Set 4 | kulhudhuffushi
# Processing Record 8 of Set 4 | gilgil
# City not found. Skipping...
# Processing Record 9 of Set 4 | raudeberg
# Processing Record 10 of Set 4 | pevek
# Processing Record 11 of Set 4 | asau
# Processing Record 12 of Set 4 | noshiro
# Processing Record 13 of Set 4 | russell
# Processing Record 14 of Set 4 | kapaa
# Processing Record 15 of Set 4 | vestmannaeyjar
# Processing Record 16 of Set 4 | clyde river
# Processing Record 17 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 4 | necochea
# Processing Record 19 of Set 4 | rio gallegos
# Processing Record 20 of Set 4 | biga
# Processing Record 21 of Set 4 | bagasara
# City not found. Skipping...
# Processing Record 22 of Set 4 | komsomolskiy
# Processing Record 23 of Set 4 | ishigaki
# Processing Record 24 of Set 4 | pitimbu
# Processing Record 25 of Set 4 | marzuq
# Processing Record 26 of Set 4 | castro
# Processing Record 27 of Set 4 | haines junction
# Processing Record 28 of Set 4 | kourou
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | vila velha
# Processing Record 31 of Set 4 | kieta
# Processing Record 32 of Set 4 | zabol
# Processing Record 33 of Set 4 | tomatlan
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | namibe
# Processing Record 36 of Set 4 | mani
# Processing Record 37 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 4 | coquimbo
# Processing Record 39 of Set 4 | jasper
# Processing Record 40 of Set 4 | bardsir
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | falmouth
# Processing Record 43 of Set 4 | qaanaaq
# Processing Record 44 of Set 4 | ban nahin
# Processing Record 45 of Set 4 | luderitz
# Processing Record 46 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 4 | san patricio
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | torit
# Processing Record 50 of Set 4 | shirokiy
# Processing Record 1 of Set 5 | marsh harbour
# Processing Record 2 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 5 | gorontalo
# Processing Record 4 of Set 5 | ust-kuyga
# Processing Record 5 of Set 5 | liverpool
# Processing Record 6 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 7 of Set 5 | jiayuguan
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | guerrero negro
# Processing Record 10 of Set 5 | east london
# Processing Record 11 of Set 5 | agadez
# Processing Record 12 of Set 5 | grindavik
# Processing Record 13 of Set 5 | ixtapa
# Processing Record 14 of Set 5 | port lincoln
# Processing Record 15 of Set 5 | nekrasovka
# Processing Record 16 of Set 5 | rosetown
# Processing Record 17 of Set 5 | cravo norte
# Processing Record 18 of Set 5 | ihosy
# Processing Record 19 of Set 5 | mango
# Processing Record 20 of Set 5 | bonthe
# Processing Record 21 of Set 5 | huarmey
# Processing Record 22 of Set 5 | puerto escondido
# Processing Record 23 of Set 5 | maple creek
# Processing Record 24 of Set 5 | khonsar
# City not found. Skipping...
# Processing Record 25 of Set 5 | sam chuk
# Processing Record 26 of Set 5 | kloulklubed
# Processing Record 27 of Set 5 | bathsheba
# Processing Record 28 of Set 5 | akureyri
# Processing Record 29 of Set 5 | pangnirtung
# Processing Record 30 of Set 5 | synya
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | manyana
# Processing Record 33 of Set 5 | boralday
# Processing Record 34 of Set 5 | saint-philippe
# Processing Record 35 of Set 5 | mandurah
# Processing Record 36 of Set 5 | kavieng
# Processing Record 37 of Set 5 | poum
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | himora
# City not found. Skipping...
# Processing Record 40 of Set 5 | ntcheu
# Processing Record 41 of Set 5 | lyubech
# Processing Record 42 of Set 5 | roebourne
# Processing Record 43 of Set 5 | muzquiz
# City not found. Skipping...
# Processing Record 44 of Set 5 | desaguadero
# Processing Record 45 of Set 5 | wagar
# Processing Record 46 of Set 5 | fairbanks
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | boffa
# Processing Record 50 of Set 5 | saldanha
# Processing Record 1 of Set 6 | cherskiy
# Processing Record 2 of Set 6 | vredendal
# Processing Record 3 of Set 6 | kyakhta
# Processing Record 4 of Set 6 | erzin
# Processing Record 5 of Set 6 | xadani
# City not found. Skipping...
# Processing Record 6 of Set 6 | orcopampa
# Processing Record 7 of Set 6 | tubuala
# Processing Record 8 of Set 6 | muzhi
# Processing Record 9 of Set 6 | saint anthony
# Processing Record 10 of Set 6 | harper
# Processing Record 11 of Set 6 | sindou
# Processing Record 12 of Set 6 | chuy
# Processing Record 13 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 14 of Set 6 | karatau
# Processing Record 15 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 6 | mahebourg
# Processing Record 17 of Set 6 | hovd
# Processing Record 18 of Set 6 | mapiri
# Processing Record 19 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 6 | astipalaia
# City not found. Skipping...
# Processing Record 21 of Set 6 | sarh
# Processing Record 22 of Set 6 | westport
# Processing Record 23 of Set 6 | berlevag
# Processing Record 24 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 6 | grand gaube
# Processing Record 26 of Set 6 | yulara
# Processing Record 27 of Set 6 | ampanihy
# Processing Record 28 of Set 6 | curup
# Processing Record 29 of Set 6 | port blair
# Processing Record 30 of Set 6 | poopo
# Processing Record 31 of Set 6 | bubaque
# Processing Record 32 of Set 6 | setermoen
# Processing Record 33 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 6 | diego de almagro
# Processing Record 35 of Set 6 | hobyo
# Processing Record 36 of Set 6 | ferme-neuve
# Processing Record 37 of Set 6 | scarborough
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | mount pleasant
# Processing Record 40 of Set 6 | kalabo
# Processing Record 41 of Set 6 | gizo
# Processing Record 42 of Set 6 | leningradskiy
# Processing Record 43 of Set 6 | istok
# Processing Record 44 of Set 6 | tautira
# Processing Record 45 of Set 6 | anamur
# Processing Record 46 of Set 6 | kibala
# Processing Record 47 of Set 6 | maceio
# Processing Record 48 of Set 6 | kahului
# Processing Record 49 of Set 6 | constitucion
# Processing Record 50 of Set 6 | kismayo
# Processing Record 1 of Set 7 | albania
# Processing Record 2 of Set 7 | okhotsk
# Processing Record 3 of Set 7 | malakal
# Processing Record 4 of Set 7 | iqaluit
# Processing Record 5 of Set 7 | tezu
# Processing Record 6 of Set 7 | madang
# Processing Record 7 of Set 7 | farsund
# Processing Record 8 of Set 7 | rosarito
# Processing Record 9 of Set 7 | lucapa
# Processing Record 10 of Set 7 | esperance
# Processing Record 11 of Set 7 | puerto del rosario
# Processing Record 12 of Set 7 | wuxi
# Processing Record 13 of Set 7 | paris
# Processing Record 14 of Set 7 | usogorsk
# Processing Record 15 of Set 7 | akersberga
# Processing Record 16 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 7 | noumea
# Processing Record 18 of Set 7 | alyangula
# Processing Record 19 of Set 7 | arraial do cabo
# Processing Record 20 of Set 7 | strezhevoy
# Processing Record 21 of Set 7 | khanpur
# Processing Record 22 of Set 7 | mezen
# Processing Record 23 of Set 7 | balanacan
# Processing Record 24 of Set 7 | ginda
# Processing Record 25 of Set 7 | sokna
# Processing Record 26 of Set 7 | beoumi
# Processing Record 27 of Set 7 | jining
# Processing Record 28 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 29 of Set 7 | paita
# Processing Record 30 of Set 7 | gamba
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | bongandanga
# Processing Record 33 of Set 7 | ponta do sol
# Processing Record 34 of Set 7 | andenes
# Processing Record 35 of Set 7 | praia da vitoria
# Processing Record 36 of Set 7 | black river
# Processing Record 37 of Set 7 | forestville
# Processing Record 38 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 7 | mahroni
# Processing Record 40 of Set 7 | totoro
# Processing Record 41 of Set 7 | ordu
# Processing Record 42 of Set 7 | charters towers
# Processing Record 43 of Set 7 | salalah
# Processing Record 44 of Set 7 | palmer
# Processing Record 45 of Set 7 | saint-joseph
# Processing Record 46 of Set 7 | coihaique
# Processing Record 47 of Set 7 | fernie
# Processing Record 48 of Set 7 | kamenka
# Processing Record 49 of Set 7 | great yarmouth
# Processing Record 50 of Set 7 | vagur
# Processing Record 1 of Set 8 | biltine
# Processing Record 2 of Set 8 | karratha
# Processing Record 3 of Set 8 | bud
# Processing Record 4 of Set 8 | camacha
# Processing Record 5 of Set 8 | eyl
# Processing Record 6 of Set 8 | carnarvon
# Processing Record 7 of Set 8 | ponta delgada
# Processing Record 8 of Set 8 | perth
# Processing Record 9 of Set 8 | santa cruz
# Processing Record 10 of Set 8 | salinopolis
# Processing Record 11 of Set 8 | turukhansk
# Processing Record 12 of Set 8 | wanning
# Processing Record 13 of Set 8 | auki
# Processing Record 14 of Set 8 | port hardy
# Processing Record 15 of Set 8 | hannibal
# Processing Record 16 of Set 8 | olga
# Processing Record 17 of Set 8 | miltenberg
# Processing Record 18 of Set 8 | tyukhtet
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | padang
# Processing Record 21 of Set 8 | moron
# Processing Record 22 of Set 8 | thaba-tseka
# Processing Record 23 of Set 8 | clarksburg
# Processing Record 24 of Set 8 | norman wells
# Processing Record 25 of Set 8 | najran
# Processing Record 26 of Set 8 | kamuli
# Processing Record 27 of Set 8 | mezhdurechensk
# Processing Record 28 of Set 8 | sturgis
# Processing Record 29 of Set 8 | richards bay
# Processing Record 30 of Set 8 | muli
# Processing Record 31 of Set 8 | mount isa
# Processing Record 32 of Set 8 | inongo
# Processing Record 33 of Set 8 | saint george
# Processing Record 34 of Set 8 | sambava
# Processing Record 35 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 8 | vila franca do campo
# Processing Record 37 of Set 8 | matagami
# Processing Record 38 of Set 8 | abu samrah
# Processing Record 39 of Set 8 | bilibino
# Processing Record 40 of Set 8 | opuwo
# Processing Record 41 of Set 8 | torgau
# Processing Record 42 of Set 8 | kalianget
# Processing Record 43 of Set 8 | bereda
# Processing Record 44 of Set 8 | pindwara
# Processing Record 45 of Set 8 | urumqi
# Processing Record 46 of Set 8 | natal
# Processing Record 47 of Set 8 | chicama
# Processing Record 48 of Set 8 | bossangoa
# Processing Record 49 of Set 8 | vanimo
# Processing Record 50 of Set 8 | surovikino
# Processing Record 1 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 9 | barcelos
# Processing Record 3 of Set 9 | hofn
# Processing Record 4 of Set 9 | lancaster
# Processing Record 5 of Set 9 | crixas
# Processing Record 6 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 9 | sioux lookout
# Processing Record 8 of Set 9 | sainte-marie
# Processing Record 9 of Set 9 | karpenision
# City not found. Skipping...
# Processing Record 10 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 9 | evensk
# Processing Record 12 of Set 9 | puerto colombia
# Processing Record 13 of Set 9 | itupiranga
# Processing Record 14 of Set 9 | lita
# Processing Record 15 of Set 9 | humaita
# Processing Record 16 of Set 9 | cap malheureux
# Processing Record 17 of Set 9 | ewa beach
# Processing Record 18 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 19 of Set 9 | tingi
# Processing Record 20 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 9 | mayo
# Processing Record 22 of Set 9 | lagoa
# Processing Record 23 of Set 9 | portmore
# Processing Record 24 of Set 9 | plouzane
# Processing Record 25 of Set 9 | adrar
# Processing Record 26 of Set 9 | atbasar
# Processing Record 27 of Set 9 | caala
# Processing Record 28 of Set 9 | keffi
# Processing Record 29 of Set 9 | takoradi
# Processing Record 30 of Set 9 | silver city
# Processing Record 31 of Set 9 | el banco
# Processing Record 32 of Set 9 | bambanglipuro
# Processing Record 33 of Set 9 | nishihara
# Processing Record 34 of Set 9 | orocue
# Processing Record 35 of Set 9 | golkoy
# Processing Record 36 of Set 9 | vilcun
# Processing Record 37 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 38 of Set 9 | banda aceh
# Processing Record 39 of Set 9 | nanfeng
# Processing Record 40 of Set 9 | dano
# Processing Record 41 of Set 9 | nemuro
# Processing Record 42 of Set 9 | dodola
# Processing Record 43 of Set 9 | forbes
# Processing Record 44 of Set 9 | portland
# Processing Record 45 of Set 9 | isangel
# Processing Record 46 of Set 9 | viedma
# Processing Record 47 of Set 9 | vostok
# Processing Record 48 of Set 9 | makokou
# Processing Record 49 of Set 9 | tunxi
# City not found. Skipping...
# Processing Record 50 of Set 9 | san cristobal
# Processing Record 1 of Set 10 | lichinga
# Processing Record 2 of Set 10 | herat
# Processing Record 3 of Set 10 | yuci
# Processing Record 4 of Set 10 | kokstad
# Processing Record 5 of Set 10 | kanniyakumari
# Processing Record 6 of Set 10 | tateyama
# Processing Record 7 of Set 10 | verkhnevilyuysk
# Processing Record 8 of Set 10 | bundaberg
# Processing Record 9 of Set 10 | egvekinot
# Processing Record 10 of Set 10 | sitka
# Processing Record 11 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 10 | zhanaozen
# Processing Record 14 of Set 10 | urubicha
# Processing Record 15 of Set 10 | saskylakh
# Processing Record 16 of Set 10 | vaitape
# Processing Record 17 of Set 10 | makungu
# Processing Record 18 of Set 10 | bilma
# Processing Record 19 of Set 10 | shelburne
# Processing Record 20 of Set 10 | dong hoi
# Processing Record 21 of Set 10 | manjakandriana
# Processing Record 22 of Set 10 | shenkursk
# Processing Record 23 of Set 10 | iskateley
# Processing Record 24 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 10 | puerto ayacucho
# Processing Record 26 of Set 10 | grand-lahou
# Processing Record 27 of Set 10 | limoges
# Processing Record 28 of Set 10 | saint-augustin
# Processing Record 29 of Set 10 | shawinigan
# Processing Record 30 of Set 10 | beisfjord
# Processing Record 31 of Set 10 | yaan
# Processing Record 32 of Set 10 | phan thiet
# Processing Record 33 of Set 10 | lumby
# Processing Record 34 of Set 10 | codrington
# Processing Record 35 of Set 10 | santiago del estero
# Processing Record 36 of Set 10 | sorong
# Processing Record 37 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 38 of Set 10 | boa vista
# Processing Record 39 of Set 10 | jinxi
# Processing Record 40 of Set 10 | otjimbingwe
# Processing Record 41 of Set 10 | talcahuano
# Processing Record 42 of Set 10 | dzhebariki-khaya
# Processing Record 43 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 44 of Set 10 | urengoy
# Processing Record 45 of Set 10 | gisborne
# Processing Record 46 of Set 10 | basco
# Processing Record 47 of Set 10 | vao
# Processing Record 48 of Set 10 | inirida
# Processing Record 49 of Set 10 | ostrovnoy
# Processing Record 50 of Set 10 | dubuque
# Processing Record 1 of Set 11 | zemio
# Processing Record 2 of Set 11 | japura
# Processing Record 3 of Set 11 | narsaq
# Processing Record 4 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record 5 of Set 11 | ondjiva
# Processing Record 6 of Set 11 | kodiak
# Processing Record 7 of Set 11 | orleans
# Processing Record 8 of Set 11 | santa marta
# Processing Record 9 of Set 11 | lompoc
# Processing Record 10 of Set 11 | assiniboia
# Processing Record 11 of Set 11 | visnes
# Processing Record 12 of Set 11 | acari
# Processing Record 13 of Set 11 | port keats
# Processing Record 14 of Set 11 | olbia
# Processing Record 15 of Set 11 | mgandu
# Processing Record 16 of Set 11 | lyaskelya
# Processing Record 17 of Set 11 | zhigansk
# Processing Record 18 of Set 11 | den helder
# Processing Record 19 of Set 11 | nuevo progreso
# Processing Record 20 of Set 11 | bethanien
# Processing Record 21 of Set 11 | tupiza
# Processing Record 22 of Set 11 | chapais
# Processing Record 23 of Set 11 | rocha
# Processing Record 24 of Set 11 | bac lieu
# Processing Record 25 of Set 11 | dukat
# Processing Record 26 of Set 11 | troitsk
# Processing Record 27 of Set 11 | barra patuca
# Processing Record 28 of Set 11 | thinadhoo
# Processing Record 29 of Set 11 | eustis
# Processing Record 30 of Set 11 | umm kaddadah
# Processing Record 31 of Set 11 | san estanislao
# Processing Record 32 of Set 11 | carberry
# Processing Record 33 of Set 11 | lumeje
# Processing Record 34 of Set 11 | lock haven
# Processing Record 35 of Set 11 | kedgwick
# Processing Record 36 of Set 11 | honningsvag
# Processing Record 37 of Set 11 | bontang
# Processing Record 38 of Set 11 | tiznit
# Processing Record 39 of Set 11 | bairiki
# Processing Record 40 of Set 11 | camabatela
# Processing Record 41 of Set 11 | itarema
# Processing Record 42 of Set 11 | lavrentiya
# Processing Record 43 of Set 11 | klyuchi
# Processing Record 44 of Set 11 | bari
# Processing Record 45 of Set 11 | tawang
# Processing Record 46 of Set 11 | bonanza
# Processing Record 47 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 11 | kualakapuas
# Processing Record 49 of Set 11 | comodoro rivadavia
# Processing Record 50 of Set 11 | tuatapere
# Processing Record 1 of Set 12 | nichinan
# Processing Record 2 of Set 12 | revelstoke
# Processing Record 3 of Set 12 | ponferrada
# Processing Record 4 of Set 12 | ribeira brava
# Processing Record 5 of Set 12 | anadyr
# Processing Record 6 of Set 12 | tadine
# Processing Record 7 of Set 12 | kayes
# Processing Record 8 of Set 12 | sterling
# Processing Record 9 of Set 12 | gashua
# Processing Record 10 of Set 12 | hericourt
# Processing Record 11 of Set 12 | sungairaya
# Processing Record 12 of Set 12 | poronaysk
# Processing Record 13 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 12 | luganville
# Processing Record 15 of Set 12 | coos bay
# Processing Record 16 of Set 12 | lashio
# Processing Record 17 of Set 12 | bulungu
# Processing Record 18 of Set 12 | gamovo
# Processing Record 19 of Set 12 | payakumbuh
# Processing Record 20 of Set 12 | colomi
# Processing Record 21 of Set 12 | maragogi
# Processing Record 22 of Set 12 | sanchor
# Processing Record 23 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 12 | aquiraz
# Processing Record 26 of Set 12 | virginia beach
# Processing Record 27 of Set 12 | aksarka
# Processing Record 28 of Set 12 | nouadhibou
# Processing Record 29 of Set 12 | tortoli
# Processing Record 30 of Set 12 | sumenep
# Processing Record 31 of Set 12 | buzmeyin
# Processing Record 32 of Set 12 | fierze
# City not found. Skipping...
# Processing Record 33 of Set 12 | priiskovyy
# Processing Record 34 of Set 12 | rome
# Processing Record 35 of Set 12 | clinton
# Processing Record 36 of Set 12 | balkanabat
# Processing Record 37 of Set 12 | kontagora
# Processing Record 38 of Set 12 | anloga
# Processing Record 39 of Set 12 | eskhar
# Processing Record 40 of Set 12 | buin
# Processing Record 41 of Set 12 | hendek
# Processing Record 42 of Set 12 | kresek
# Processing Record 43 of Set 12 | amapa
# Processing Record 44 of Set 12 | lata
# Processing Record 45 of Set 12 | chaman
# Processing Record 46 of Set 12 | ornskoldsvik
# Processing Record 47 of Set 12 | majene
# Processing Record 48 of Set 12 | usinsk
# Processing Record 49 of Set 12 | san juan
# Processing Record 50 of Set 12 | buala
# Processing Record 1 of Set 13 | margate
# Processing Record 2 of Set 13 | jackson
# Processing Record 3 of Set 13 | campbell river
# Processing Record 4 of Set 13 | zharkent
# Processing Record 5 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 6 of Set 13 | privolzhskiy
# Processing Record 7 of Set 13 | laizhou
# Processing Record 8 of Set 13 | almaty
# Processing Record 9 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 13 | simao
# Processing Record 11 of Set 13 | voh
# Processing Record 12 of Set 13 | rundu
# Processing Record 13 of Set 13 | kununurra
# Processing Record 14 of Set 13 | cayenne
# Processing Record 15 of Set 13 | mutoko
# Processing Record 16 of Set 13 | panna
# Processing Record 17 of Set 13 | yuanping
# Processing Record 18 of Set 13 | tagusao
# Processing Record 19 of Set 13 | terrace bay
# Processing Record 20 of Set 13 | plettenberg bay
# Processing Record 21 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 13 | harer
# Processing Record 23 of Set 13 | sangar
# Processing Record 24 of Set 13 | sao joao da barra
# Processing Record 25 of Set 13 | batsfjord
# Processing Record 26 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 27 of Set 13 | ternate
# Processing Record 28 of Set 13 | stonewall
# Processing Record 29 of Set 13 | manakara
# Processing Record 30 of Set 13 | west wendover
# Processing Record 31 of Set 13 | santa isabel do rio negro
# Processing Record 32 of Set 13 | qafsah
# City not found. Skipping...
# Processing Record 33 of Set 13 | sapernoye
# Processing Record 34 of Set 13 | kot isa khan
# Processing Record 35 of Set 13 | shache
# Processing Record 36 of Set 13 | tandil
# Processing Record 37 of Set 13 | luwuk
# Processing Record 38 of Set 13 | biak
# Processing Record 39 of Set 13 | mut
# Processing Record 40 of Set 13 | mahibadhoo
# Processing Record 41 of Set 13 | chervone
# Processing Record 42 of Set 13 | zhoucheng
# Processing Record 43 of Set 13 | denpasar
# Processing Record 44 of Set 13 | morlaix
# Processing Record 45 of Set 13 | hunterville
# Processing Record 46 of Set 13 | matara
# Processing Record 47 of Set 13 | conceicao do araguaia
# Processing Record 48 of Set 13 | jiazi
# Processing Record 49 of Set 13 | yerbogachen
# Processing Record 50 of Set 13 | tura
# Processing Record 1 of Set 14 | pec
# Processing Record 2 of Set 14 | tarauaca
# Processing Record 3 of Set 14 | lasem
# Processing Record 4 of Set 14 | ardon
# Processing Record 5 of Set 14 | kjopsvik
# Processing Record 6 of Set 14 | pochutla
# Processing Record 7 of Set 14 | makarov
# Processing Record 8 of Set 14 | kirakira
# Processing Record 9 of Set 14 | hagavik
# Processing Record 10 of Set 14 | port macquarie
# Processing Record 11 of Set 14 | saint-leu
# Processing Record 12 of Set 14 | semey
# Processing Record 13 of Set 14 | ola
# Processing Record 14 of Set 14 | tamandare
# Processing Record 15 of Set 14 | kolondieba
# Processing Record 16 of Set 14 | areia branca
# Processing Record 17 of Set 14 | brandon
# Processing Record 18 of Set 14 | west odessa
# Processing Record 19 of Set 14 | longkou
# Processing Record 20 of Set 14 | sao miguel do araguaia
# Processing Record 21 of Set 14 | zeya
# Processing Record 22 of Set 14 | chengde
# Processing Record 23 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 14 | popondetta
# Processing Record 25 of Set 14 | kalmunai
# Processing Record 26 of Set 14 | amancio
# City not found. Skipping...
# Processing Record 27 of Set 14 | pasni
# Processing Record 28 of Set 14 | mandalgovi
# Processing Record 29 of Set 14 | kavaratti
# Processing Record 30 of Set 14 | damietta
# Processing Record 31 of Set 14 | kudahuvadhoo
# Processing Record 32 of Set 14 | barguzin
# Processing Record 33 of Set 14 | puerto narino
# Processing Record 34 of Set 14 | maumere
# Processing Record 35 of Set 14 | kuzhener
# Processing Record 36 of Set 14 | lososina
# Processing Record 37 of Set 14 | shingu
# Processing Record 38 of Set 14 | east norriton
# Processing Record 39 of Set 14 | te anau
# Processing Record 40 of Set 14 | abu dhabi
# Processing Record 41 of Set 14 | tecoanapa
# Processing Record 42 of Set 14 | nouakchott
# Processing Record 43 of Set 14 | ormara
# Processing Record 44 of Set 14 | benguela
# Processing Record 45 of Set 14 | naze
# Processing Record 46 of Set 14 | porto velho
# Processing Record 47 of Set 14 | gasa
# Processing Record 48 of Set 14 | cabinda
# Processing Record 49 of Set 14 | mocuba
# Processing Record 50 of Set 14 | oksfjord
# Processing Record 1 of Set 15 | buzdyak
# Processing Record 2 of Set 15 | college
# Processing Record 3 of Set 15 | jalu
# Processing Record 4 of Set 15 | valparaiso
# Processing Record 5 of Set 15 | pinotepa nacional
# Processing Record 6 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 15 | cairns
# Processing Record 8 of Set 15 | havelock
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
Weather_Data_df = pd.DataFrame(city_data)
Weather_Data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Husavik      IS  66.0449  -17.3389     26.51        77
# 1          Novonikolsk      RU  43.8506  131.8645      6.58        90
# 2        Alice Springs      AU -23.7000  133.8833     74.75        94
# 3              Mataura      NZ -46.1927  168.8643     56.39        74
# 4         Punta Arenas      CL -53.1500  -70.9167     59.02        62
# ..                 ...     ...      ...       ...       ...       ...
# 639               Jalu      LY  29.0331   21.5482     58.44        39
# 640         Valparaiso      CL -33.0393  -71.6273     69.44        67
# 641  Pinotepa Nacional      MX  16.3167  -98.0167     82.45        55
# 642             Cairns      AU -16.9167  145.7667     76.95        88
# 643           Havelock      US  34.8791  -76.9013     36.05        76
#
#      Cloudiness  Wind Speed       Description
# 0            25       15.23  scattered clouds
# 1            51        3.02     broken clouds
# 2           100       13.80     moderate rain
# 3            99        1.32        light rain
# 4            75       19.57        light rain
# ..          ...         ...               ...
# 639           5       14.54         clear sky
# 640          40       11.50  scattered clouds
# 641          18        3.22        few clouds
# 642          75        8.05     broken clouds
# 643         100       13.00   overcast clouds
#
# [644 rows x 9 columns]

# %%
Weather_Data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
